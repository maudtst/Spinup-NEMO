# %%
import numpy as np
import xarray as xr
import sys
import matplotlib.pyplot as plt
import densite
import restart

import importlib
importlib.reload(restart)
# Out:
# <module 'restart' from '/home/mtissot/SpinUp/jumper/restart.py'>

# %% [markdown]
# # **Load files**

# %% [markdown]
# ### 1.1 - Predictions

# %%
zos_new    = np.load("/data/mtissot/simus_predicted/zos.npy")       #or ssh sea surface height  t*y*x
so_new     = np.load("/data/mtissot/simus_predicted/so.npy")        #salinity t*z*y*x
thetao_new = np.load("/data/mtissot/simus_predicted/thetao.npy")    #temperature t*z*y*x

print(np.shape(zos_new))
print(np.shape(so_new))
print(np.shape(thetao_new))
# Out:
# (30, 331, 360)
# (30, 75, 331, 360)
# (30, 75, 331, 360)

# %% [markdown]
# ### 1.2 - Maskdataset

# %%
MASKdataset    = xr.open_dataset('/thredds/idris/work/ues27zx/eORCA1.4.2_mesh_mask_modJD.nc',decode_times=False) 
print("features : ", list(MASKdataset.keys()))
# Out:
# features :  ['e1f', 'e1t', 'e1u', 'e1v', 'e2f', 'e2t', 'e2u', 'e2v', 'e3f_0', 'e3t_0', 'e3t_1d', 'e3u_0', 'e3uw_0', 'e3v_0', 'e3vw_0', 'e3w_0', 'e3w_1d', 'ff_f', 'ff_t', 'fmask', 'gdept_0', 'gdept_1d', 'gdepw_0', 'gdepw_1d', 'glamf', 'glamt', 'glamu', 'glamv', 'gphif', 'gphit', 'gphiu', 'gphiv', 'mbathy', 'misf', 'nav_lev', 'time_counter', 'tmask', 'tmaskutil', 'umask', 'umaskutil', 'vmask', 'vmaskutil', 'gridx', 'gridy']

# %% [markdown]
# ### 1.3 - Restart file

# %%
restarts_file = "/thredds/idris/work/ues27zx/Restarts/"
restart_name  = "OCE_CM65v420-LR-CdL-pi-01_19141231_restart_0142.nc"  #pour chaque fichier de restart 
Restart       = xr.open_dataset(restarts_file+restart_name,decode_times=False)

x_slice,y_slice = restart.getXYslice(Restart)

print("x slice  : ",x_slice)
print("y slice  : ",y_slice)
print("\nfeatures : ", list(Restart.keys()))
# Out:
# x slice  :  slice(38, 57, None)
# y slice  :  slice(154, 168, None)
#
# features :  ['xx', 'yy', 'kt', 'ndastp', 'adatrj', 'ntime', 'fwfisf_par_b', 'isf_hc_par_b', 'isf_sc_par_b', 'nn_fsbc', 'ssu_m', 'ssv_m', 'sst_m', 'sss_m', 'ssh_m', 'e3t_m', 'frq_m', 'rnf_b', 'rnf_hc_b', 'rnf_sc_b', 'utau_b', 'vtau_b', 'qns_b', 'emp_b', 'sfx_b', 'en', 'avt_k', 'avm_k', 'dissl', 'ub2_b', 'vb2_b', 'un_bf', 'vn_bf', 'sbc_hc_b', 'sbc_sc_b', 'qsr_hc_b', 'fraqsr_1lev', 'frc_v', 'frc_t', 'frc_s', 'surf_ini', 'ssh_ini', 'e3t_ini', 'tmask_ini', 'hc_loc_ini', 'sc_loc_ini', 'rdt', 'sshb', 'ub', 'vb', 'tb', 'sb', 'sshn', 'un', 'vn', 'tn', 'sn', 'rhop']

# %% [markdown]
# # **Update one restart file**

# %% [markdown]
# ### 2.1 - zos, so and Thetao update

# %%
fig, axes = plt.subplots(1,3, figsize=(14,4))
a = axes[0].pcolor(Restart["sshn"][0])
fig.colorbar(a, ax=axes[0])
a = axes[1].pcolor(Restart["sn"][0,0])
fig.colorbar(a, ax=axes[1])
a = axes[2].pcolor(Restart["tn"][0,0])
fig.colorbar(a, ax=axes[2])

# %%
restart.update_pred(Restart,zos_new,so_new,thetao_new)

print("sn shape    : ",np.shape(Restart["sn"]))
print("tn shape    : ",np.shape(Restart["tn"]))
print("sshn shape  : ",np.shape(Restart["sshn"]))
print("sss_m shape : ",np.shape(Restart["sss_m"]))
print("sss_t shape : ",np.shape(Restart["sst_m"]))
# Out:
# sn shape    :  (1, 75, 14, 19)
# tn shape    :  (1, 75, 14, 19)
# sshn shape  :  (1, 14, 19)
# sss_m shape :  (1, 14, 19)
# sss_t shape :  (1, 14, 19)

# %%
fig, axes = plt.subplots(1,3, figsize=(14,4))
a = axes[0].pcolor(Restart["sshn"][0])
fig.colorbar(a, ax=axes[0]);
a = axes[1].pcolor(Restart["sn"][0,0])
fig.colorbar(a, ax=axes[1]);
a = axes[2].pcolor(Restart["tn"][0,0])
fig.colorbar(a, ax=axes[2]);

# %% [markdown]
# ### 2.2 - e3t and deptht

# %%
#Should be calculated in the update_e3tm function

array      = xr.open_dataset("/scratchu/mtissot/SIMUp6Y/CM65v420-LR-CdL-pi-01_18500101_19491231_1M_so.nc.YAVG.nc" , decode_times=False)
deptht_new = np.tile(array.deptht.values, (1,360,331,1)).transpose(0,3,2,1)[:,:,y_slice,x_slice]  #thickness of all 75 levels
print(np.shape(deptht_new))
# Out:
# (1, 75, 14, 19)

# %%
fig = plt.figure(figsize=(5,4))
plt.pcolor(Restart["e3t_m"][0],vmin=1.016)
plt.colorbar()
x=Restart["e3t_m"][0,0]

# %%
e3t_new,depth_mauvais = restart.update_e3tm(MASKdataset,Restart)

print("e3_m shape   : ",np.shape(Restart["e3t_m"]))
print("e3t shape    : ",np.shape(e3t_new))
print("deptht shape : ",np.shape(deptht_new))
# Out:
# e3_m shape   :  (1, 14, 19)
# e3t shape    :  (1, 75, 14, 19)
# deptht shape :  (1, 75, 14, 19)

# %%
fig = plt.figure(figsize=(5,4))
plt.pcolor(Restart["e3t_m"][0],vmin=1.016)
plt.colorbar()

# %% [markdown]
# ### 2.3 - rhop update

# %%
fig = plt.figure(figsize=(5,4))
plt.pcolor(Restart["rhop"][0,0],vmin=1017,vmax=np.max(Restart["rhop"][0,0]))
plt.colorbar()

# %%
restart.update_rhop(Restart,thetao_new,so_new)

print("rhop shape : ",np.shape(Restart["rhop"]))
# Out:
# rhop shape :  (1, 75, 14, 19)

# %%
fig = plt.figure(figsize=(5,4))
plt.pcolor(Restart["rhop"][0,0])#,vmin=1017,vmax=np.max(Restart["rhop"][0,0]))
plt.colorbar()

# %% [markdown]
# other visu on rhop

# %%
rhop_new     = densite.sigma_n(thetao_new[-1:,:,y_slice,x_slice],so_new[-1:,:,y_slice,x_slice],n=0)
diff_rhop    = np.diff(rhop_new[-1], axis=0)/e3t_new[0,:-1]#,:,y_slice,x_slice] #differentiel de la densité
xr_rhop_new  = xr.DataArray(rhop_new, dims=("time_counter", "nav_lev", "y", "x"), name="rhop")

fig, axes = plt.subplots(1, 2, figsize=(14, 4))

for i in range(Restart["rhop"].sizes['x']): 
    for j in range(Restart["rhop"].sizes['y']):
        xr_rhop_new.isel(time_counter=0, x=i, y=j).plot(ax=axes[0])     
axes[0].set_title('Density as a function of depth')


alpha_values = np.where(np.isnan(zos_new[-1,y_slice,x_slice]), 0, 1.0)  
a=axes[1].pcolor(np.nanmin(diff_rhop, axis=0) < 0, alpha=alpha_values)  # Plot with transparency
axes[1].set_title('Min of density')
fig.colorbar(a, ax=axes[1])
plt.show()
# Out:
# /tmp/ipykernel_252712/10714228.py:14: RuntimeWarning: All-NaN axis encountered
#   a=axes[1].pcolor(np.nanmin(diff_rhop, axis=0) < 0, alpha=alpha_values)  # Plot with transparency

# %%
rho_insitu_reg = restart.regularize_rho(np.copy(rhop_new))
diff_reg = np.diff(rho_insitu_reg[0], axis=0)#/e3t[0,:-1]#,:,y_slice,x_slice] #differentiel de la densité

for i in range(19): 
    for j in range(14):
        plt.plot(diff_reg[:,j,i])

# %% [markdown]
# ### 2.4 - velocities update

# %%
fig, axes = plt.subplots(1,2, figsize=(14,4))
a = axes[0].pcolor(Restart["vn"][0,0])
fig.colorbar(a, ax=axes[0])
a = axes[1].pcolor(Restart["un"][0,0])
fig.colorbar(a, ax=axes[1])

# %%
import importlib
importlib.reload(restart)
# Out:
# <module 'restart' from '/home/mtissot/SpinUp/jumper/restart.py'>

# %%
restart.get_u_velocity(Restart,MASKdataset,e3t_new[0])
restart.get_v_velocity(Restart,MASKdataset,e3t_new[0])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 restart.get_u_velocity(Restart,MASKdataset,e3t_new[0])
#       2 restart.get_v_velocity(Restart,MASKdataset,e3t_new[0])
#
# File ~/SpinUp/jumper/restart.py:103, in get_u_velocity(array, maskarray, e3t_new)
#     101 diff_y = np.roll(rhop_insitu_new[-1],shift=-1,axis=1) - rhop_insitu_new[-1]
#     102 u_new  = 9.81/(rhop_insitu_new[-1]*ff_f) * np.cumsum(diff_y*e3t_new/e2t,axis=0)   # + U_0
# --> 103 un_new = add_bottom_velocity(un.values,u_new.values,umask)
#     105 array['un']    = toXarray(un_new,"un")
#     106 array['ub']    = toXarray(un_new,"ub")
#
# File ~/SpinUp/jumper/restart.py:111, in add_bottom_velocity(v_restart, v_update, mask)
#     110 def add_bottom_velocity(v_restart,v_update,mask):
# --> 111     time,deptht,y,x = np.shape(v_restart)
#     112     for i in range(x):
#     113         for j in range(y):
#
# ValueError: not enough values to unpack (expected 4, got 3)

# %%
fig, axes = plt.subplots(1,2, figsize=(14,4))
a = axes[0].pcolor(Restart["vn"][0,0])
fig.colorbar(a, ax=axes[0])
a = axes[1].pcolor(Restart["un"][0,0])
fig.colorbar(a, ax=axes[1])

# %%
#Changement des variables de restart now : vitesses
vn    = Restart.variables['vn']                            #initial zonal velocity
un    = Restart.variables['un']                            #initial meridional velocity
e3t   = MASKdataset["e3t_0"].values[0,:,y_slice,x_slice]   #initial z axis cell's thickness on grid T 
e2t   = MASKdataset["e2t"].values[0,y_slice,x_slice]       #initial x axis cell's thickness on grid T 
e1t   = MASKdataset["e1t"].values[0,y_slice,x_slice]       #initial y axis cell's thickness on grid T 
umask = MASKdataset["umask"].values[:,:,y_slice,x_slice]   #bathy mask on grid U  
vmask = MASKdataset["vmask"].values[:,:,y_slice,x_slice]   #bathy mask on grid V  
ff_f  = MASKdataset["ff_f"].values[0,y_slice,x_slice]      #corriolis 

rho_insitu = rhop_new

print("Info for v velocity reconstruction : \n")
print("vn shape         : ", np.shape(vn))
print("e3t shape        : ", np.shape(e3t))
print("e1t shape        : ", np.shape(e1t))
print("fff_f shape      : ", np.shape(ff_f))
print("fff_f shape      : ", np.shape(ff_f))
print("rho_insitu shape : ", np.shape(rho_insitu))
print("vmask shape      : ", np.shape(vmask))

#equation from ... p...
diff_x = -np.roll(rho_insitu,shift=1,axis=2) + rho_insitu
v_new  = 9.81/(rho_insitu*ff_f) * np.cumsum(diff_x*e3t/e1t,axis=0) # + V_0  
v_new  = v_new.squeeze()

#equation from ... p...
diff_y = np.roll(rho_insitu[-1],shift=-1,axis=1) - rho_insitu[-1] 
u_new  = 9.81/(rho_insitu[-1]*ff_f) * np.cumsum(diff_y*e3t/e2t,axis=0)   # + U_0

import restart
import importlib
importlib.reload(restart)
vn_new = restart.add_bottom_velocity(vn,v_new,vmask)
un_new = restart.add_bottom_velocity(un,u_new,umask)

print("vn shape :", np.shape(vn_new))
print("un shape :", np.shape(un_new))

Restart['vn'] = xr.DataArray(vn_new, dims=("time_counter","deptht", "y", "x"), name="vn")    
Restart['un'] = xr.DataArray(un_new, dims=("time_counter","deptht", "y", "x"), name="un")
# Out:
# Info for v velocity reconstruction :
#
# vn shape         :  (1, 75, 14, 19)
# e3t shape        :  (75, 14, 19)
# e1t shape        :  (14, 19)
# fff_f shape      :  (14, 19)
# fff_f shape      :  (14, 19)
# rho_insitu shape :  (1, 75, 14, 19)
# vmask shape      :  (1, 75, 14, 19)
# vn shape : (1, 75, 14, 19)
# un shape : (1, 75, 14, 19)

# %%
fig, axes = plt.subplots(2,4, figsize=(10,6))
axes[0,0].pcolor(vn[0,0])
axes[0,1].pcolor(vmask[-1,0])
axes[0,2].pcolor(v_new[0])
axes[0,3].pcolor(vn_new[-1,0])

axes[1,0].pcolor(un[0,0])
axes[1,1].pcolor(umask[-1,0])
axes[1,2].pcolor(u_new[0])
axes[1,3].pcolor(un_new[-1,0])

names = ["vn","vmask","v","vn update","un","umask","u","un update"]
for i, ax in enumerate(axes.flat):
    ax.set_title(names[i])

plt.tight_layout()

# %%
fig, axes = plt.subplots(1,3, figsize=(12,4))
for i in range(np.shape(vn)[3]):
    for j in range(np.shape(vn)[2]):
        axes[0].plot(vn_new[0,:,j,i]-v_new[:,j,i])
        axes[1].plot(un_new[0,:,j,i]-u_new[:,j,i])
        axes[0].set_title("vn and v difference along z axis")
        axes[1].set_title("un and u difference along z axis")
        axes[2].plot(vn[-1,:,j,i]-vn_new[-1,:,j,i])

# %% [markdown]
# # **Save restart file**

# %%
Restart = Restart.rename_vars({'xx': 'x','yy':'y'})             #inverse transformation of x and y vars
#Restart.to_netcdf(restarts_file+restart_name)
